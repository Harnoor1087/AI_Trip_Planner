# %%
print("ok")
# Out:
# ok

# %%
from dotenv import load_dotenv

# %%
from langchain_groq import ChatGroq

# %%
llm=ChatGroq(model="llama-3.3-70b-versatile")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 llm=ChatGroq(model="llama-3.3-70b-versatile")
#
# File d:\AI_Trip_Planner\env\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File d:\AI_Trip_Planner\env\Lib\site-packages\langchain_groq\chat_models.py:530, in ChatGroq.validate_environment(self)
#     528 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     529 if not self.client:
# --> 530     self.client = groq.Groq(
#     531         **client_params, **sync_specific
#     532     ).chat.completions
#     533 if not self.async_client:
#     534     async_specific: dict[str, Any] = {"http_client": self.http_async_client}
#
# File d:\AI_Trip_Planner\env\Lib\site-packages\groq\_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
llm.invoke("hi")
# Out:
# AIMessage(content="It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 36, 'total_tokens': 59, 'completion_time': 0.044798959, 'completion_tokens_details': None, 'prompt_time': 0.002221323, 'prompt_tokens_details': None, 'queue_time': 0.058584827, 'total_time': 0.047020282}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fb41e-89a3-7551-9be9-adf15bad675e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 36, 'output_tokens': 23, 'total_tokens': 59})

# %%
from langchain.tools import tool
@tool
def multiply(a: int, b: int) -> int:
    """
    Multiply two integers.

    Args:
        a (int): The first integer.
        b (int): The second integer.

    Returns:
        int: The product of a and b.
    """
    return a * b
multiply
# Out:
# StructuredTool(name='multiply', description='Multiply two integers.\n\nArgs:\n    a (int): The first integer.\n    b (int): The second integer.\n\nReturns:\n    int: The product of a and b.', args_schema=<class 'langchain_core.utils.pydantic.multiply'>, func=<function multiply at 0x000002B32C360180>)

# %%
from langchain_core.tools import StructuredTool

# %%
from pydantic import BaseModel

class WeatherInput(BaseModel):
    city: str

# %%
def get_weather(city: str) -> str:
    """
    Get the weather for a given city.

    Args:
        city (str): The name of the city.

    Returns:
        str: A string describing the weather in the city.
    """
    return f"The weather in {city} is sunny."

# %%
weather_tool = StructuredTool.from_function(
    func=get_weather,
    name="get_weather",
    description="Fetches real-time weather data for a city",
    args_schema=WeatherInput,  
)

# %%
from typing import ClassVar, Type

from pydantic import BaseModel, Field

class WeatherInput(BaseModel):
    city: str = Field(..., description="City name")
    units: str = Field("metric", description="metric or imperial")

class GetWeatherTool(StructuredTool):
    name: ClassVar[str] = "get_weather"
    description: ClassVar[str] = (
        "Fetches weather data for a city"
    )
    args_schema: ClassVar[Type[BaseModel]] = WeatherInput

    def _run(self, city: str, units: str = "metric") -> str:
        return get_weather(city, units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       3 class WeatherInput(BaseModel):
#       4     city: str = Field(..., description="City name")
#       5     units: str = Field("metric", description="metric or imperial")
#       6
# ----> 7 class GetWeatherTool(StructuredTool):
#       8     name: ClassVar[str] = "get_weather"
#       9     description: ClassVar[str] = (
#      10         "Fetches weather data for a city"
#
# Cell In[22], line 8, in GetWeatherTool()
#       7 from pydantic import BaseModel, Field
# ----> 8
#       9 class WeatherInput(BaseModel):
#      10     city: str = Field(..., description="City name")
#      11     units: str = Field("metric", description="metric or imperial")
#
# NameError: name 'ClassVar' is not defined
